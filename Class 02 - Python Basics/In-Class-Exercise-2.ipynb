# %% [markdown]
# ## In-Class Exercise #2

# %% [markdown]
# 1. Write code that prints the word "ECO4971 is Great" 10 times.

# %% [markdown]
# 2. Write a function called "compare" that accepts two numeric inputs a and b.
#
# The function should prints one of the three statements based on whether A is larger or smaller than B:
# * A is bigger than B
# * B is bigger than A
# * A and B are equal

# %% [markdown]
# 3. The FizzBuzz game is a simple counting game, where you count up from 1, but instead of saying any multiple of 3 say "Fizz", instead of saying a multiple of 5, say "Buzz", and any number that is both a multiple of 3 and 5 is "FizzBuzz".
#
# For example, the first 6 numbers are:
# 1
# 2
# Fizz
# 4
# Buzz
# 6
#
# Write code that prints out the first 50 items in the FizzBuzz list

# %%
x = list(range(1,51))
print(x)

# %%
x = list(range(1,20))

def myfunction(x): 
    SOMETHING HERE

# %%
x = 1

def myfunction(a):
    print(a)
    
myfunction(2)
print(a)

# %%
x = 7

#CASE 1: You want to run everything that is satisfied
#CASE 2: You want to only run the first thing that is satisfied
#else tells the computer we are in case 2

if x == 1: 
    print("x is 1")
elif x > 0: 
    print("x is greater than 0")
elif x > 5: 
    print("COOL")
# Out:
# x is greater than 0
